# %% [markdown]
# <a href="https://colab.research.google.com/github/dj202410320-png/dlfkd/blob/main/%EC%9D%B4%EB%9E%91_1%EC%A3%BC%EC%B0%A8_%EA%B9%83%ED%97%88%EB%B8%8C_%EC%A0%80%EC%9E%A5%EC%86%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("너 적어 숫자:"))
print(num,"단")
for i in range(1,10):
  print(num, "X", i, "=", num*i)
# Out:
# 너 적어 숫자:100
# 100 단
# 100 X 1 = 100
# 100 X 2 = 200
# 100 X 3 = 300
# 100 X 4 = 400
# 100 X 5 = 500
# 100 X 6 = 600
# 100 X 7 = 700
# 100 X 8 = 800
# 100 X 9 = 900
